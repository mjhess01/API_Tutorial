# %%
baseurl = "http://api.weatherapi.com/v1"
key = ""

# %%
# http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
import requests
import pandas as pd

# %%
city = "Chengdu"
baseurl = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Chengdu',
#   'region': 'Sichuan',
#   'country': 'China',
#   'lat': 30.6667,
#   'lon': 104.0667,
#   'tz_id': 'Asia/Shanghai',
#   'localtime_epoch': 1777314237,
#   'localtime': '2026-04-28 02:23'},
#  'current': {'last_updated_epoch': 1777313700,
#   'last_updated': '2026-04-28 02:15',
#   'temp_c': 17.3,
#   'temp_f': 63.1,
#   'is_day': 0,
#   'condition': {'text': 'Light rain',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/296.png',
#    'code': 1183},
#   'wind_mph': 6.5,
#   'wind_kph': 10.4,
#   'wind_degree': 331,
#   'wind_dir': 'NNW',
#   'pressure_mb': 1014.0,
#   'pressure_in': 29.94,
#   'precip_mm': 0.88,
#   'precip_in': 0.03,
#   'humidity': 72,
#   'cloud': 100,
#   'feelslike_c': 17.3,
#   'feelslike_f': 63.1,
#   'windchill_c': 15.4,
#   'windchill_f': 59.8,
#   'heatindex_c': 15.4,
#   'heatindex_f': 59.8,
#   'dewpoint_c': 13.9,
#   'dewpoint_f': 57.1,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 0.0,
#   'gust_mph': 9.4,
#   'gust_kph': 15.1,
#   'short_rad': 0,
#   'diff_rad': 0,
#   'dni': 0,
#   'gti': 0}}

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f, humidity, wind_mph
# Out:
# (63.1, 72, 6.5)

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f"Weather for {location['name']}, {location['region']}")
        print(f"Temperature: {current['temp_f']} °F / {current['temp_c']} °C")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']} mph")

    else:
        print(f"Error fetching data for {city}: {response.status_code}")

# %%
get_weather("Boston")
# Out:
# Weather for Boston, Massachusetts
# Temperature: 55.9 °F / 13.3 °C
# Condition: Sunny
# Humidity: 57%
# Wind Speed: 8.3 mph

# %%
get_weather("Minneapolis")
# Out:
# Weather for Minneapolis, Minnesota
# Temperature: 55.9 °F / 13.3 °C
# Condition: Light rain
# Humidity: 90%
# Wind Speed: 6.0 mph

# %%
cities = ["Chengdu", "Louisville", "Minneapolis", "Dallas", "Portland"]
weather_data = []

for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            "City": data['location']['name'],
            "Temperature": data['current']['temp_f'],
            "Condition": data['current']['condition']['text'],
            "Humidity": data['current']['humidity'],
            "Wind Speed": data['current']['wind_mph']
        })
    else:
        print("Error fetching data")

# %%
weather_data
# Out:
# [{'City': 'Chengdu',
#   'Temperature': 63.1,
#   'Condition': 'Light rain',
#   'Humidity': 72,
#   'Wind Speed': 6.5},
#  {'City': 'Louisville',
#   'Temperature': 73.9,
#   'Condition': 'Partly cloudy',
#   'Humidity': 57,
#   'Wind Speed': 12.1},
#  {'City': 'Minneapolis',
#   'Temperature': 55.9,
#   'Condition': 'Light rain',
#   'Humidity': 90,
#   'Wind Speed': 6.0},
#  {'City': 'Dallas',
#   'Temperature': 87.1,
#   'Condition': 'Partly Cloudy',
#   'Humidity': 59,
#   'Wind Speed': 12.1},
#  {'City': 'Portland',
#   'Temperature': 53.1,
#   'Condition': 'Partly cloudy',
#   'Humidity': 69,
#   'Wind Speed': 3.4}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#           City  Temperature      Condition  Humidity  Wind Speed
# 0      Chengdu         63.1     Light rain        72         6.5
# 1   Louisville         73.9  Partly cloudy        57        12.1
# 2  Minneapolis         55.9     Light rain        90         6.0
# 3       Dallas         87.1  Partly Cloudy        59        12.1
# 4     Portland         53.1  Partly cloudy        69         3.4

# %%
weather_df.to_csv("sample_weather_data.csv", index=False)
