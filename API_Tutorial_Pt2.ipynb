# %%
import requests
import pandas as pd
from datetime import datetime

# %%
api_key = "f25777e33d814028914164824262704"
baseurl =  "http://api.weatherapi.com/v1/"
# f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
city="Louisville"

# %%
response = requests.get(f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}")
response.status_code
# Out:
# 200

# %%
data = response.json()
data['current']
# Out:
# {'last_updated_epoch': 1777329000,
#  'last_updated': '2026-04-27 18:30',
#  'temp_c': 24.4,
#  'temp_f': 75.9,
#  'is_day': 1,
#  'condition': {'text': 'Light rain',
#   'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#   'code': 1183},
#  'wind_mph': 12.3,
#  'wind_kph': 19.8,
#  'wind_degree': 181,
#  'wind_dir': 'S',
#  'pressure_mb': 1010.0,
#  'pressure_in': 29.81,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 60,
#  'cloud': 100,
#  'feelslike_c': 25.5,
#  'feelslike_f': 77.9,
#  'windchill_c': 26.2,
#  'windchill_f': 79.1,
#  'heatindex_c': 27.2,
#  'heatindex_f': 81.0,
#  'dewpoint_c': 16.5,
#  'dewpoint_f': 61.7,
#  'vis_km': 16.0,
#  'vis_miles': 9.0,
#  'uv': 0.6,
#  'gust_mph': 19.2,
#  'gust_kph': 30.9,
#  'short_rad': 142.72,
#  'diff_rad': 86.78,
#  'dni': 0.0,
#  'gti': 80.52}

# %%
forecast_url = f"{baseurl}forecast.json?key={api_key}&q={city}&days=3"
forecast_response = requests.get(forecast_url)
forecast_response.status_code
# Out:
# 200

# %%
forecast_data = forecast_response.json()
forecast = forecast_data['forecast']['forecastday']

# %%
forecast_3_days_summary = []
for day in forecast:
    forecast_3_days_summary.append(f"{day['date']}: High {day['day']['maxtemp_f']}F, Low {day['day']['mintemp_f']} - {day['day']['condition']['text']}")

# %%
forecast_3_days_summary
# Out:
# ['2026-04-27: High 82.9F, Low 52.7 - Patchy rain nearby',
#  '2026-04-28: High 77.7F, Low 62.4 - Heavy rain',
#  '2026-04-29: High 68.3F, Low 54.1 - Moderate rain']

# %% [markdown]
# %A = day of the week
# %B = name of the month
# %#d = date itself

# %%
forecast_3_days_summary = []
for day in forecast:
    date_obj = datetime.strptime(day['date'], '%Y-%m-%d')
    formatted_date = date_obj.strftime('%A, %B %#d')
    forecast_3_days_summary.append(f"{formatted_date}: High {day['day']['maxtemp_f']}F / Low {day['day']['mintemp_f']} - {day['day']['condition']['text']}")

forecast_3_days_summary
# Out:
# ['Monday, April 27: High 82.9F / Low 52.7 - Patchy rain nearby',
#  'Tuesday, April 28: High 77.7F / Low 62.4 - Heavy rain',
#  'Wednesday, April 29: High 68.3F / Low 54.1 - Moderate rain']

# %%
today = pd.Timestamp.now().strftime("%Y-%m-%d")
astronomy_url = f"{baseurl}astronomy.json?key={api_key}&q={city}&dt={today}"

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f"Weather for {location['name']}, {location['region']}")
        print(f"Temperature: {current['temp_f']} °F / {current['temp_c']} °C")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']} mph")

    else:
        print(f"Error fetching data for {city}: {response.status_code}")

# %%
def get_city_data(city, api_key):
    get_weather(city)     #get current weather
    #get a forecast
    #get astronomical data
    #get anything else you want (challenge)

    #build a summary for the city, save that summary into a dictionary
